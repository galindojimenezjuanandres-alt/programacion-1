# %% [markdown]
# <a href="https://colab.research.google.com/github/galindojimenezjuanandres-alt/programacion-1/blob/main/quizz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# QUIZZ
#
# 26/MARZO

# %%
# %%writefile promedio.py

import statistics

def calcular_promedio(n1, n2, n3):
  return (n1 + n2 + n3) / 3

def mediana(n1, n2, n3):
  return statistics.median([n1,n2,n3])

def moda(n1, n2, n3):
  return statistics.mode([n1,n2,n3])
# Out:
# Overwriting promedio.py

# %%
importlib.reload(promedio)

import promedio
prom = promedio.calcular_promedio(notas[0],notas[1],notas[2])
mediana = promedio.mediana(notas[0],notas[1],notas[2])
moda = promedio.moda(notas[0],notas[1],notas[2])

print("estudiante: ", nombre)
print("promedio: ", prom)
print("mediana: ", mediana)
print("moda: ", moda)

if prom >= 3 :
  print("aprobo")
else:
  print("reprobo")
# Out:
# estudiante:  juan
# promedio:  2.6666666666666665
# mediana:  3.0
# moda:  4.0
# reprobo
